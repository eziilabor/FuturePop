# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

# %%
# import data and sort it by country in alphabetical order then year (ascending) 
df = pd.read_csv('futurePopData.csv')
df['YEARS'] = df['YEARS'].astype(int)

# Sort by Country first, then by Year
countries = df.sort_values(by=['COUNTRY', 'YEARS'])
#countries = countries[['COUNTRY', 'YEARS', 'HDI', 'FERTILITY RATE', 'FEMALE LITERACY', 'GDP PER CAPITA', 'CHILD MORTALITY', 'MEAN AGE AT FIRST BIRTH']]

print(countries)
# Out:
#          COUNTRY    HDI  FERTILITY RATE  FEMALE LITERACY  \
# 579  Afghanistan  0.501             NaN            0.266
# 386  Afghanistan  0.486            4.90            0.266
# 193  Afghanistan  0.495            4.62            0.266
# 0    Afghanistan  0.496            4.80            0.266
# 580      Albania  0.794             NaN            0.983
# ..           ...    ...             ...              ...
# 191       Zambia  0.595            4.10            0.843
# 771     Zimbabwe  0.582             NaN            0.912
# 578     Zimbabwe  0.581            3.80            0.912
# 385     Zimbabwe  0.594            3.89            0.912
# 192     Zimbabwe  0.598            3.70            0.912
#
#      FEMALE LABOR PARTICIPATION  GDP PER CAPITA  URBANIZATION RATE  \
# 579                         NaN      510.787063                NaN
# 386                         NaN      356.496214                NaN
# 193                         NaN      510.787063                NaN
# 0                          0.05      413.800000               0.27
# 580                         NaN     5370.777500                NaN
# ..                          ...             ...                ...
# 191                        0.54     1235.100000               0.47
# 771                         NaN     1730.453910                NaN
# 578                         NaN     1724.387271                NaN
# 385                         NaN     1730.453910                NaN
# 192                        0.60     2656.400000               0.33
#
#      CHILD MORTALITY  MEAN AGE AT FIRST BIRTH  YEARS
# 579             61.0                     19.9   2020
# 386             59.0                     19.9   2021
# 193             57.0                     19.9   2022
# 0               56.0                     19.9   2023
# 580              9.0                     26.6   2020
# ..               ...                      ...    ...
# 191             45.0                     19.2   2023
# 771             50.0                     20.3   2020
# 578             48.0                     20.3   2021
# 385             46.0                     20.3   2022
# 192             44.0                     20.3   2023
#
# [772 rows x 10 columns]

# %%
#linear comparison between fertility rate and other columns
countries.select_dtypes(include='number').corr()['FERTILITY RATE']
# Out:
# HDI                          -0.835419
# FERTILITY RATE                1.000000
# FEMALE LITERACY              -0.784020
# FEMALE LABOR PARTICIPATION   -0.003257
# GDP PER CAPITA               -0.434678
# URBANIZATION RATE            -0.501123
# CHILD MORTALITY               0.763165
# MEAN AGE AT FIRST BIRTH      -0.651693
# YEARS                        -0.017840
# Name: FERTILITY RATE, dtype: float64

# %%
#Random Forest
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

df = countries.copy()  
df['FertilityRate_LastYear'] = df.groupby('COUNTRY')['FERTILITY RATE'].shift(1)

features = ['HDI', 'FertilityRate_LastYear', 'FEMALE LITERACY',
            'GDP PER CAPITA', 'CHILD MORTALITY', 'MEAN AGE AT FIRST BIRTH']

train_df = df[df['YEARS'] < 2023].copy()
test_df = df[df['YEARS'] == 2023].copy()

train_df.dropna(subset=features + ['FERTILITY RATE'], inplace=True)
test_df.dropna(subset=features + ['FERTILITY RATE'], inplace=True)

X_train = train_df[features]
y_train = train_df['FERTILITY RATE']
X_test = test_df[features]
y_test = test_df['FERTILITY RATE']

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train_scaled, y_train)

y_pred = model.predict(X_test_scaled)
print("MSE on 2023 data:", mean_squared_error(y_test, y_pred))

predict_2024 = df[df['YEARS'] == 2023].copy()
predict_2024['FertilityRate_LastYear'] = predict_2024['FERTILITY RATE']
X_2024 = predict_2024[features].dropna()
X_2024_scaled = scaler.transform(X_2024)
fertility_2024_preds = model.predict(X_2024_scaled)

predict_2024 = predict_2024.loc[X_2024.index]
predict_2024['Predicted Fertility Rate 2024'] = fertility_2024_preds
pd.set_option('display.max_rows', None)

predict_2024['COUNTRY'] = predict_2024['COUNTRY'].str.strip()
print(predict_2024[['COUNTRY', 'Predicted Fertility Rate 2024']])
predict_2024[['COUNTRY', 'Predicted Fertility Rate 2024']].to_csv('random_forest.csv', index=False)
# Out:
# MSE on 2023 data: 0.28699301279567396
#                             COUNTRY  Predicted Fertility Rate 2024
# 0                       Afghanistan                       4.655600
# 1                           Albania                       1.675300
# 2                           Algeria                       2.488700
# 4                            Angola                       5.087100
# 6                         Argentina                       1.969600
# 7                           Armenia                       2.118800
# 8                         Australia                       1.806800
# 9                           Austria                       1.605800
# 10                       Azerbaijan                       1.805200
# 11                          Bahamas                       1.871700
# 12                          Bahrain                       1.887200
# 13                       Bangladesh                       2.175100
# 15                          Belarus                       1.504200
# 16                          Belgium                       1.780500
# 17                           Belize                       2.271900
# 18                            Benin                       5.051700
# 19                           Bhutan                       1.903700
# 20                          Bolivia                       2.248967
# 21           Bosnia and Herzegovina                       1.488700
# 23                           Brazil                       1.811200
# 25                         Bulgaria                       1.616900
# 26                     Burkina Faso                       4.355400
# 27                          Burundi                       4.747600
# 29                         Cambodia                       2.381667
# 30                         Cameroon                       4.010100
# 31                           Canada                       1.632400
# 32         Central African Republic                       5.609500
# 33                             Chad                       5.678800
# 34                            Chile                       1.618800
# 35                            China                       1.481800
# 36                         Colombia                       1.842400
# 37                          Comoros                       3.264300
# 38                            Congo                       3.840300
# 39   Congo (Democratic Republic of)                       5.385200
# 40                       Costa Rica                       1.826000
# 41                    Cote d'Ivoire                       3.902600
# 42                          Croatia                       1.561700
# 43                             Cuba                       1.695900
# 44                           Cyprus                       1.519200
# 46                          Denmark                       1.798700
# 48                         Dominica                       1.986700
# 49               Dominican Republic                       2.103400
# 50                          Ecuador                       1.826700
# 51                            Egypt                       2.559433
# 52                      El Salvador                       1.999000
# 53                Equatorial Guinea                       3.453000
# 54                          Eritrea                       3.469100
# 55                          Estonia                       1.560900
# 57                         Ethiopia                       3.098200
# 58                             Fiji                       2.267800
# 59                          Finland                       1.563600
# 60                           France                       1.892600
# 61                            Gabon                       3.271200
# 62                           Gambia                       3.886700
# 63                          Georgia                       1.767500
# 64                          Germany                       1.638400
# 65                            Ghana                       3.459100
# 66                           Greece                       1.417200
# 68                        Guatemala                       2.340333
# 69                           Guinea                       4.433300
# 71                           Guyana                       2.174767
# 72                            Haiti                       2.731700
# 73                         Honduras                       2.149467
# 75                          Hungary                       1.540200
# 76                          Iceland                       1.871500
# 77                            India                       2.158967
# 78                        Indonesia                       2.157633
# 79                             Iran                       1.804600
# 80                             Iraq                       2.909933
# 81                          Ireland                       1.843400
# 82                           Israel                       2.472100
# 83                            Italy                       1.404500
# 84                          Jamaica                       1.971100
# 85                            Japan                       1.342500
# 86                           Jordan                       2.410833
# 87                       Kazakhstan                       2.305500
# 88                            Kenya                       3.141400
# 89                         Kiribati                       2.628600
# 91                           Kuwait                       1.925300
# 92                       Kyrgyzstan                       2.243400
# 93                             Laos                       2.473433
# 94                           Latvia                       1.583100
# 95                          Lebanon                       2.054467
# 96                          Lesotho                       2.711467
# 97                          Liberia                       3.866300
# 100                       Lithuania                       1.518400
# 101                      Luxembourg                       1.599000
# 102                      Madagascar                       3.803900
# 103                          Malawi                       3.461100
# 104                        Malaysia                       1.697900
# 105                        Maldives                       1.695100
# 106                            Mali                       5.569200
# 107                           Malta                       1.536600
# 109                      Mauritania                       3.996500
# 111                          Mexico                       2.006700
# 113                         Moldova                       1.726200
# 114                        Mongolia                       2.132333
# 115                      Montenegro                       1.684800
# 116                         Morocco                       2.292300
# 117                      Mozambique                       4.722700
# 118                         Myanmar                       2.348400
# 119                         Namibia                       2.951267
# 121                           Nepal                       2.082533
# 122                     Netherlands                       1.673200
# 123                     New Zealand                       1.750800
# 124                       Nicaragua                       2.047933
# 125                           Niger                       6.381000
# 126                         Nigeria                       4.748700
# 127                 North Macedonia                       1.518200
# 128                          Norway                       1.750700
# 129                            Oman                       2.511000
# 130                        Pakistan                       3.554500
# 131                           Palau                       2.218900
# 133                          Panama                       2.332700
# 134                Papua New Guinea                       3.377367
# 135                        Paraguay                       2.023200
# 136                            Peru                       2.121367
# 137                     Philippines                       2.529100
# 138                          Poland                       1.519700
# 139                        Portugal                       1.491500
# 140                           Qatar                       1.842700
# 141                         Romania                       1.655600
# 142                          Russia                       1.589900
# 143                          Rwanda                       3.400400
# 148                      San Marino                       1.451800
# 149           Sao Tome and Principe                       3.366900
# 150                    Sauda Arabia                       2.183000
# 151                         Senegal                       3.798700
# 152                          Serbia                       1.496900
# 154                    Sierra Leone                       3.742300
# 155                       Singapore                       1.415200
# 156                        Slovakia                       1.617800
# 157                        Slovenia                       1.626100
# 160                    South Africa                       2.175500
# 90                      South Korea                       1.331900
# 161                     South Sudan                       3.631800
# 162                           Spain                       1.325300
# 163                       Sri Lanka                       2.134800
# 164                           Sudan                       4.377100
# 166                          Sweden                       1.695900
# 167                     Switzerland                       1.591800
# 168                           Syria                       2.563567
# 169                      Tajikistan                       2.519233
# 170                        Tanzania                       4.516200
# 171                        Thailand                       1.577000
# 172                     Timor-Leste                       2.874700
# 173                            Togo                       4.247200
# 174                           Tonga                       2.483900
# 177                          Turkey                       1.949100
# 178                    Turkmenistan                       2.213700
# 180                          Uganda                       4.289000
# 181                         Ukraine                       1.577700
# 182            United Arab Emirates                       1.578000
# 183                  United Kingdom                       1.769900
# 184                   United States                       1.806700
# 185                         Uruguay                       1.708900
# 186                      Uzbekistan                       2.382400
# 188                       Venezuela                       2.391800
# 189                         Vietnam                       2.247200
# 190                           Yemen                       4.557700
# 191                          Zambia                       3.195400
# 192                        Zimbabwe                       3.612300

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

df = countries.copy()
df['FertilityRate_LastYear'] = df.groupby('COUNTRY')['FERTILITY RATE'].shift(1)

features = ['HDI', 'FertilityRate_LastYear', 'FEMALE LITERACY',
            'GDP PER CAPITA', 'CHILD MORTALITY', 'MEAN AGE AT FIRST BIRTH']

train_df = df[df['YEARS'] < 2023].copy()
test_df = df[df['YEARS'] == 2023].copy()

train_df.dropna(subset=features + ['FERTILITY RATE'], inplace=True)
test_df.dropna(subset=features + ['FERTILITY RATE'], inplace=True)

X_train = train_df[features]
y_train = train_df['FERTILITY RATE']
X_test = test_df[features]
y_test = test_df['FERTILITY RATE']

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

model = Sequential([
    Dense(32, input_dim=len(features), activation='relu'),  # One hidden layer with 32 neurons
    Dense(1)  # Output layer for regression
])

model.compile(optimizer='adam', loss='mean_squared_error')

model.fit(X_train_scaled, y_train, epochs=100, batch_size=16, verbose=1)

y_pred = model.predict(X_test_scaled).flatten()
print("MSE on 2023 data:", mean_squared_error(y_test, y_pred))

predict_2024 = df[df['YEARS'] == 2023].copy()
predict_2024['FertilityRate_LastYear'] = predict_2024['FERTILITY RATE']
X_2024 = predict_2024[features].dropna()

X_2024_scaled = scaler.transform(X_2024)
fertility_2024_preds = model.predict(X_2024_scaled).flatten()

predict_2024 = predict_2024.loc[X_2024.index]
predict_2024['Predicted Fertility Rate 2024'] = fertility_2024_preds

print(predict_2024[['COUNTRY', 'Predicted Fertility Rate 2024']])
predict_2024[['COUNTRY', 'Predicted Fertility Rate 2024']].to_csv('neural_network.csv', index=False)
# Out:
# Epoch 1/100
# C:\Users\iyerk\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 9.0531
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.6795
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.7812
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.2585
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.3065
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4518
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.8918
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.3280
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0710
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.3948
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.0689
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7472
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4089
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1169
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8642
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1511
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1709
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7525
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7778
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8122
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6980
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5432
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7288
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5459
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6211
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5141
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5118
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5001
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5132
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4893
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3955
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5293
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5514
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4839
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4497
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4280
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3088
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3370
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3264
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3738
# Epoch 41/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3218
# Epoch 42/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2542
# Epoch 43/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4229
# Epoch 44/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3652
# Epoch 45/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2859
# Epoch 46/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3727
# Epoch 47/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2481
# Epoch 48/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3044
# Epoch 49/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2321
# Epoch 50/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2939
# Epoch 51/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2121
# Epoch 52/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3372
# Epoch 53/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2430
# Epoch 54/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2364
# Epoch 55/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2236
# Epoch 56/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3424
# Epoch 57/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2049
# Epoch 58/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3034
# Epoch 59/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2855
# Epoch 60/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2683
# Epoch 61/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2437
# Epoch 62/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2455
# Epoch 63/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2497
# Epoch 64/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2367
# Epoch 65/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2565
# Epoch 66/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2146
# Epoch 67/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2016
# Epoch 68/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2446
# Epoch 69/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1913
# Epoch 70/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1908
# Epoch 71/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1984
# Epoch 72/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2387
# Epoch 73/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2439
# Epoch 74/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1770
# Epoch 75/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2217
# Epoch 76/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2577
# Epoch 77/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1560
# Epoch 78/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2246
# Epoch 79/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2707
# Epoch 80/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1961
# Epoch 81/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2007
# Epoch 82/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2948
# Epoch 83/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1790
# Epoch 84/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2213
# Epoch 85/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2553
# Epoch 86/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2233
# Epoch 87/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1733
# Epoch 88/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2130
# Epoch 89/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1711
# Epoch 90/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1776
# Epoch 91/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2063
# Epoch 92/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2535
# Epoch 93/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1633
# Epoch 94/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2186
# Epoch 95/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2346
# Epoch 96/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1991
# Epoch 97/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1798
# Epoch 98/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1451
# Epoch 99/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2214
# Epoch 100/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1701
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# MSE on 2023 data: 0.2959326490885427
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#                             COUNTRY  Predicted Fertility Rate 2024
# 0                       Afghanistan                       4.484157
# 1                           Albania                       1.543834
# 2                           Algeria                       2.674842
# 4                            Angola                       4.811356
# 6                         Argentina                       2.023976
# 7                           Armenia                       1.818200
# 8                         Australia                       1.704719
# 9                           Austria                       1.617667
# 10                       Azerbaijan                       1.789429
# 11                          Bahamas                       1.841566
# 12                          Bahrain                       1.660320
# 13                       Bangladesh                       2.131988
# 15                          Belarus                       1.617968
# 16                          Belgium                       1.701951
# 17                           Belize                       1.705767
# 18                            Benin                       4.519282
# 19                           Bhutan                       2.014903
# 20                          Bolivia                       2.271572
# 21           Bosnia and Herzegovina                       1.602464
# 23                           Brazil                       1.512831
# 25                         Bulgaria                       1.555481
# 26                     Burkina Faso                       4.403599
# 27                          Burundi                       4.640773
# 29                         Cambodia                       2.269227
# 30                         Cameroon                       4.353196
# 31                           Canada                       1.443741
# 32         Central African Republic                       5.655445
# 33                             Chad                       6.057570
# 34                            Chile                       1.475051
# 35                            China                       1.319821
# 36                         Colombia                       1.793103
# 37                          Comoros                       3.344012
# 38                            Congo                       3.902166
# 39   Congo (Democratic Republic of)                       5.835319
# 40                       Costa Rica                       1.419612
# 41                    Cote d'Ivoire                       4.034314
# 42                          Croatia                       1.590550
# 43                             Cuba                       1.627197
# 44                           Cyprus                       1.557523
# 46                          Denmark                       1.828304
# 48                         Dominica                       1.574017
# 49               Dominican Republic                       1.895507
# 50                          Ecuador                       1.708740
# 51                            Egypt                       2.135465
# 52                      El Salvador                       1.819852
# 53                Equatorial Guinea                       3.695801
# 54                          Eritrea                       3.489441
# 55                          Estonia                       1.415682
# 57                         Ethiopia                       3.760045
# 58                             Fiji                       1.712613
# 59                          Finland                       2.038061
# 60                           France                       1.661546
# 61                            Gabon                       3.020390
# 62                           Gambia                       3.686974
# 63                          Georgia                       1.770752
# 64                          Germany                       1.698595
# 65                            Ghana                       3.204952
# 66                           Greece                       1.614335
# 68                        Guatemala                       2.005696
# 69                           Guinea                       4.537333
# 71                           Guyana                       1.576043
# 72                            Haiti                       2.917629
# 73                         Honduras                       2.322258
# 75                          Hungary                       1.527931
# 76                          Iceland                       1.889785
# 77                            India                       1.867259
# 78                        Indonesia                       2.030698
# 79                             Iran                       1.669406
# 80                             Iraq                       2.698815
# 81                          Ireland                       2.023640
# 82                           Israel                       2.177175
# 83                            Italy                       1.658344
# 84                          Jamaica                       1.757740
# 85                            Japan                       1.536597
# 86                           Jordan                       2.166952
# 87                       Kazakhstan                       2.358147
# 88                            Kenya                       3.151758
# 89                         Kiribati                       3.092043
# 91                           Kuwait                       2.231410
# 92                       Kyrgyzstan                       1.549640
# 93                             Laos                       2.489193
# 94                           Latvia                       1.473582
# 95                          Lebanon                       2.267089
# 96                          Lesotho                       3.255230
# 97                          Liberia                       4.149298
# 100                       Lithuania                       1.376368
# 101                      Luxembourg                       2.383634
# 102                      Madagascar                       4.337056
# 103                          Malawi                       3.567594
# 104                        Malaysia                       1.576167
# 105                        Maldives                       1.589810
# 106                            Mali                       5.543746
# 107                           Malta                       1.410553
# 109                      Mauritania                       3.977923
# 111                          Mexico                       1.633864
# 113                         Moldova                       1.751676
# 114                        Mongolia                       2.410517
# 115                      Montenegro                       1.648589
# 116                         Morocco                       1.808179
# 117                      Mozambique                       4.612299
# 118                         Myanmar                       2.273260
# 119                         Namibia                       2.983859
# 121                           Nepal                       2.065693
# 122                     Netherlands                       1.740476
# 123                     New Zealand                       1.616130
# 124                       Nicaragua                       2.080226
# 125                           Niger                       6.337101
# 126                         Nigeria                       4.820370
# 127                 North Macedonia                       1.588039
# 128                          Norway                       1.920912
# 129                            Oman                       1.799367
# 130                        Pakistan                       3.483521
# 131                           Palau                       1.478355
# 133                          Panama                       1.590424
# 134                Papua New Guinea                       2.857525
# 135                        Paraguay                       1.925501
# 136                            Peru                       1.991627
# 137                     Philippines                       1.991677
# 138                          Poland                       1.414969
# 139                        Portugal                       1.468556
# 140                           Qatar                       1.778623
# 141                         Romania                       1.536215
# 142                          Russia                       1.471588
# 143                          Rwanda                       3.397028
# 148                      San Marino                       1.680137
# 149           Sao Tome and Principe                       3.173369
# 150                    Sauda Arabia                       2.039769
# 151                         Senegal                       3.426993
# 152                          Serbia                       1.694998
# 154                    Sierra Leone                       4.436775
# 155                       Singapore                       1.801504
# 156                        Slovakia                       1.408947
# 157                        Slovenia                       1.587727
# 160                    South Africa                       2.117031
# 90                      South Korea                       1.426474
# 161                     South Sudan                       4.335832
# 162                           Spain                       1.492880
# 163                       Sri Lanka                       1.774546
# 164                           Sudan                       3.868248
# 166                          Sweden                       1.733048
# 167                     Switzerland                       1.991605
# 168                           Syria                       2.534578
# 169                      Tajikistan                       2.745031
# 170                        Tanzania                       4.311487
# 171                        Thailand                       1.488933
# 172                     Timor-Leste                       2.703925
# 173                            Togo                       3.831580
# 174                           Tonga                       2.604771
# 177                          Turkey                       1.393706
# 178                    Turkmenistan                       2.150692
# 180                          Uganda                       4.099170
# 181                         Ukraine                       1.626811
# 182            United Arab Emirates                       1.524219
# 183                  United Kingdom                       1.685480
# 184                   United States                       1.805949
# 185                         Uruguay                       1.353862
# 186                      Uzbekistan                       2.949418
# 188                       Venezuela                       1.564371
# 189                         Vietnam                       1.899708
# 190                           Yemen                       4.138542
# 191                          Zambia                       4.096029
# 192                        Zimbabwe                       3.669391

# %%
actual_df = pd.read_csv('perdictionData.csv')
predicted_ran_df = pd.read_csv('randomForest.csv')
predicted_nn_df = pd.read_csv('neuralNetwork.csv')

merged_ran = pd.merge(predicted_ran_df, actual_df, how='inner', on='COUNTRY', suffixes=('_predicted','_actual'))
merged_nn = pd.merge(predicted_nn_df, actual_df, how='inner', on='COUNTRY', suffixes=('_predicted','_actual'))

print(merged_ran)
# Out:
#                       COUNTRY  Predicted Fertility Rate 2024  \
# 0                 Afghanistan                       4.655600
# 1                     Albania                       1.675300
# 2                     Algeria                       2.488700
# 3                      Angola                       5.087100
# 4                   Argentina                       1.969600
# 5                     Armenia                       2.118800
# 6                   Australia                       1.806800
# 7                     Austria                       1.605800
# 8                  Azerbaijan                       1.805200
# 9                     Bahamas                       1.871700
# 10                    Bahrain                       1.887200
# 11                 Bangladesh                       2.175100
# 12                    Belarus                       1.504200
# 13                    Belgium                       1.780500
# 14                     Belize                       2.271900
# 15                      Benin                       5.051700
# 16                     Bhutan                       1.903700
# 17                    Bolivia                       2.248967
# 18     Bosnia and Herzegovina                       1.488700
# 19                     Brazil                       1.811200
# 20                   Bulgaria                       1.616900
# 21               Burkina Faso                       4.355400
# 22                    Burundi                       4.747600
# 23                   Cambodia                       2.381667
# 24                   Cameroon                       4.010100
# 25                     Canada                       1.632400
# 26   Central African Republic                       5.609500
# 27                       Chad                       5.678800
# 28                      Chile                       1.618800
# 29                      China                       1.481800
# 30                   Colombia                       1.842400
# 31                    Comoros                       3.264300
# 32                 Costa Rica                       1.826000
# 33                    Croatia                       1.561700
# 34                       Cuba                       1.695900
# 35                     Cyprus                       1.519200
# 36                    Denmark                       1.798700
# 37                   Dominica                       1.986700
# 38         Dominican Republic                       2.103400
# 39                    Ecuador                       1.826700
# 40                      Egypt                       2.559433
# 41                El Salvador                       1.999000
# 42          Equatorial Guinea                       3.453000
# 43                    Eritrea                       3.469100
# 44                    Estonia                       1.560900
# 45                   Ethiopia                       3.098200
# 46                       Fiji                       2.267800
# 47                    Finland                       1.563600
# 48                     France                       1.892600
# 49                      Gabon                       3.271200
# 50                     Gambia                       3.886700
# 51                    Georgia                       1.767500
# 52                    Germany                       1.638400
# 53                      Ghana                       3.459100
# 54                     Greece                       1.417200
# 55                  Guatemala                       2.340333
# 56                     Guinea                       4.433300
# 57                     Guyana                       2.174767
# 58                      Haiti                       2.731700
# 59                   Honduras                       2.149467
# 60                    Hungary                       1.540200
# 61                    Iceland                       1.871500
# 62                      India                       2.158967
# 63                  Indonesia                       2.157633
# 64                       Iran                       1.804600
# 65                       Iraq                       2.909933
# 66                    Ireland                       1.843400
# 67                     Israel                       2.472100
# 68                      Italy                       1.404500
# 69                    Jamaica                       1.971100
# 70                      Japan                       1.342500
# 71                     Jordan                       2.410833
# 72                 Kazakhstan                       2.305500
# 73                      Kenya                       3.141400
# 74                   Kiribati                       2.628600
# 75                     Kuwait                       1.925300
# 76                 Kyrgyzstan                       2.243400
# 77                       Laos                       2.473433
# 78                     Latvia                       1.583100
# 79                    Lebanon                       2.054467
# 80                    Lesotho                       2.711467
# 81                    Liberia                       3.866300
# 82                  Lithuania                       1.518400
# 83                 Luxembourg                       1.599000
# 84                 Madagascar                       3.803900
# 85                     Malawi                       3.461100
# 86                   Malaysia                       1.697900
# 87                   Maldives                       1.695100
# 88                       Mali                       5.569200
# 89                      Malta                       1.536600
# 90                 Mauritania                       3.996500
# 91                     Mexico                       2.006700
# 92                    Moldova                       1.726200
# 93                   Mongolia                       2.132333
# 94                 Montenegro                       1.684800
# 95                    Morocco                       2.292300
# 96                 Mozambique                       4.722700
# 97                    Myanmar                       2.348400
# 98                    Namibia                       2.951267
# 99                      Nepal                       2.082533
# 100               Netherlands                       1.673200
# 101               New Zealand                       1.750800
# 102                 Nicaragua                       2.047933
# 103                     Niger                       6.381000
# 104                   Nigeria                       4.748700
# 105           North Macedonia                       1.518200
# 106                    Norway                       1.750700
# 107                      Oman                       2.511000
# 108                  Pakistan                       3.554500
# 109                     Palau                       2.218900
# 110                    Panama                       2.332700
# 111          Papua New Guinea                       3.377367
# 112                  Paraguay                       2.023200
# 113                      Peru                       2.121367
# 114               Philippines                       2.529100
# 115                    Poland                       1.519700
# 116                  Portugal                       1.491500
# 117                     Qatar                       1.842700
# 118                   Romania                       1.655600
# 119                    Russia                       1.589900
# 120                    Rwanda                       3.400400
# 121                San Marino                       1.451800
# 122     Sao Tome and Principe                       3.366900
# 123                   Senegal                       3.798700
# 124                    Serbia                       1.496900
# 125              Sierra Leone                       3.742300
# 126                 Singapore                       1.415200
# 127                  Slovakia                       1.617800
# 128                  Slovenia                       1.626100
# 129              South Africa                       2.175500
# 130               South Korea                       1.331900
# 131               South Sudan                       3.631800
# 132                     Spain                       1.325300
# 133                 Sri Lanka                       2.134800
# 134                     Sudan                       4.377100
# 135                    Sweden                       1.695900
# 136               Switzerland                       1.591800
# 137                     Syria                       2.563567
# 138                Tajikistan                       2.519233
# 139                  Tanzania                       4.516200
# 140                  Thailand                       1.577000
# 141               Timor-Leste                       2.874700
# 142                      Togo                       4.247200
# 143                     Tonga                       2.483900
# 144                    Turkey                       1.949100
# 145              Turkmenistan                       2.213700
# 146                    Uganda                       4.289000
# 147                   Ukraine                       1.577700
# 148      United Arab Emirates                       1.578000
# 149            United Kingdom                       1.769900
# 150             United States                       1.806700
# 151                   Uruguay                       1.708900
# 152                Uzbekistan                       2.382400
# 153                 Venezuela                       2.391800
# 154                   Vietnam                       2.247200
# 155                     Yemen                       4.557700
# 156                    Zambia                       3.195400
# 157                  Zimbabwe                       3.612300
#
#      TotalFertilityRate_EstFertilityRate_num_2024
# 0                                            4.43
# 1                                            1.55
# 2                                            2.94
# 3                                            5.70
# 4                                            2.15
# 5                                            1.65
# 6                                            1.73
# 7                                            1.52
# 8                                            1.69
# 9                                            1.44
# 10                                           1.65
# 11                                           2.07
# 12                                           1.45
# 13                                           1.76
# 14                                           2.05
# 15                                           5.34
# 16                                           1.76
# 17                                           2.20
# 18                                           1.38
# 19                                           1.74
# 20                                           1.51
# 21                                           4.02
# 22                                           4.90
# 23                                           2.17
# 24                                           4.44
# 25                                           1.58
# 26                                           3.94
# 27                                           5.24
# 28                                           1.75
# 29                                           1.55
# 30                                           1.94
# 31                                           2.61
# 32                                           1.43
# 33                                           1.46
# 34                                           1.71
# 35                                           1.49
# 36                                           1.77
# 37                                           2.01
# 38                                           2.15
# 39                                           2.21
# 40                                           2.65
# 41                                           2.02
# 42                                           4.12
# 43                                           3.43
# 44                                           1.62
# 45                                           3.84
# 46                                           2.21
# 47                                           1.74
# 48                                           1.90
# 49                                           3.21
# 50                                           3.52
# 51                                           1.95
# 52                                           1.58
# 53                                           3.56
# 54                                           1.41
# 55                                           2.52
# 56                                           4.78
# 57                                           2.05
# 58                                           2.44
# 59                                           2.33
# 60                                           1.60
# 61                                           1.94
# 62                                           2.03
# 63                                           1.96
# 64                                           1.91
# 65                                           3.10
# 66                                           1.72
# 67                                           2.92
# 68                                           1.26
# 69                                           2.05
# 70                                           1.40
# 71                                           2.87
# 72                                           2.58
# 73                                           3.16
# 74                                           2.15
# 75                                           2.21
# 76                                           2.45
# 77                                           2.24
# 78                                           1.55
# 79                                           1.71
# 80                                           2.85
# 81                                           3.93
# 82                                           1.62
# 83                                           1.63
# 84                                           3.47
# 85                                           3.19
# 86                                           1.73
# 87                                           1.70
# 88                                           5.35
# 89                                           1.51
# 90                                           3.40
# 91                                           1.79
# 92                                           1.26
# 93                                           1.87
# 94                                           1.80
# 95                                           2.25
# 96                                           4.66
# 97                                           1.97
# 98                                           2.89
# 99                                           1.85
# 100                                          1.61
# 101                                          1.85
# 102                                          1.83
# 103                                          6.64
# 104                                          4.52
# 105                                          1.53
# 106                                          1.57
# 107                                          2.64
# 108                                          3.32
# 109                                          1.70
# 110                                          2.35
# 111                                          3.79
# 112                                          1.88
# 113                                          2.15
# 114                                          2.75
# 115                                          1.32
# 116                                          1.45
# 117                                          1.90
# 118                                          1.63
# 119                                          1.52
# 120                                          3.14
# 121                                          1.54
# 122                                          3.31
# 123                                          4.06
# 124                                          1.46
# 125                                          3.61
# 126                                          1.17
# 127                                          1.60
# 128                                          1.60
# 129                                          2.27
# 130                                          1.12
# 131                                          5.09
# 132                                          1.30
# 133                                          2.13
# 134                                          4.47
# 135                                          1.67
# 136                                          1.59
# 137                                          2.69
# 138                                          3.56
# 139                                          4.27
# 140                                          1.54
# 141                                          3.98
# 142                                          4.13
# 143                                          2.65
# 144                                          1.90
# 145                                          2.02
# 146                                          5.17
# 147                                          1.22
# 148                                          1.61
# 149                                          1.63
# 150                                          1.84
# 151                                          1.75
# 152                                          2.76
# 153                                          2.18
# 154                                          2.03
# 155                                          2.82
# 156                                          4.42
# 157                                          3.47

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

actual = merged_ran['TotalFertilityRate_EstFertilityRate_num_2024']
predicted = merged_ran['Predicted Fertility Rate 2024']

mae = mean_absolute_error(actual, predicted)
mse = mean_squared_error(actual, predicted)
r2 = r2_score(actual, predicted)

print("Random Forest")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R²): {r2}")
# Out:
# Random Forest
# Mean Absolute Error (MAE): 0.22452953586430371
# Mean Squared Error (MSE): 0.1315412205064121
# R-squared (R²): 0.8955831783322845

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

actual = merged_nn['TotalFertilityRate_EstFertilityRate_num_2024']
predicted = merged_nn['Predicted Fertility Rate 2024']

mae = mean_absolute_error(actual, predicted)
mse = mean_squared_error(actual, predicted)
r2 = r2_score(actual, predicted)

print("Neural Network")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R²): {r2}")
# Out:
# Neural Network
# Mean Absolute Error (MAE): 0.31142658670886075
# Mean Squared Error (MSE): 0.18272574025589247
# R-squared (R²): 0.8549531397006404
